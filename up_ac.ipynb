# %% [markdown]
# ## up-ac Basic Example
#
# This python notebook shows an examplary usage of the up-ac module.
#
# Project page: [![Open GitHub](https://img.shields.io/badge/see-Github-579aca?logo=github)](https://github.com/DimitriWeiss/up-ac)
#
# In particulat, this notebook will go through an example of Algorithm Configuration for ENHSP, an Expressic Numeric Heuristic Search Planner. For this we use SMAC, a Sequential Model-Based Optimization for
# General Algorithm Configuration.

# %% [markdown]
# ### Dependencies

# %% [markdown]
# We are updating Java because the default version on the notebook is not up to date enough for the Java version of enhsp. Then, we install the up_ac library from GitHub. We use the `--pre` flag to install the latest build dependencies for our `enhsp` planner.

# %%
# !apt install openjdk-17-jdk openjdk-17-jre
# !pip install git+https://github.com/DimitriWeiss/up-ac.git
# !pip install --pre unified-planning[enhsp]
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# openjdk-17-jdk is already the newest version (17.0.8.1+1~us1-0ubuntu1~22.04).
# openjdk-17-jre is already the newest version (17.0.8.1+1~us1-0ubuntu1~22.04).
# 0 upgraded, 0 newly installed, 0 to remove and 18 not upgraded.
# Collecting git+https://github.com/DimitriWeiss/up-ac.git
#   Cloning https://github.com/DimitriWeiss/up-ac.git to /tmp/pip-req-build-n1lp2sek
#   Running command git clone --filter=blob:none --quiet https://github.com/DimitriWeiss/up-ac.git /tmp/pip-req-build-n1lp2sek
#   Resolved https://github.com/DimitriWeiss/up-ac.git to commit ae7a6f9d2aca1e6321fb80757cd698be2f9bab4c
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: unified-planning in /usr/local/lib/python3.10/dist-packages (from up-ac==0.0.1) (1.0.0)
# Requirement already satisfied: smac in /usr/local/lib/python3.10/dist-packages (from up-ac==0.0.1) (2.0.2)
# Requirement already satisfied: ConfigSpace in /usr/local/lib/python3.10/dist-packages (from up-ac==0.0.1) (0.7.1)
# Requirement already satisfied: tarski in /usr/local/lib/python3.10/dist-packages (from up-ac==0.0.1) (0.8.2)
# Requirement already satisfied: pebble in /usr/local/lib/python3.10/dist-packages (from up-ac==0.0.1) (5.0.3)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from up-ac==0.0.1) (0.3.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ConfigSpace->up-ac==0.0.1) (1.23.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from ConfigSpace->up-ac==0.0.1) (3.1.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from ConfigSpace->up-ac==0.0.1) (1.11.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from ConfigSpace->up-ac==0.0.1) (4.5.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from ConfigSpace->up-ac==0.0.1) (10.1.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from smac->up-ac==0.0.1) (5.9.5)
# Requirement already satisfied: pynisher>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from smac->up-ac==0.0.1) (1.0.9)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from smac->up-ac==0.0.1) (1.3.2)
# Requirement already satisfied: scikit-learn>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from smac->up-ac==0.0.1) (1.2.2)
# Requirement already satisfied: pyrfr>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from smac->up-ac==0.0.1) (0.9.0)
# Requirement already satisfied: dask[distributed] in /usr/local/lib/python3.10/dist-packages (from smac->up-ac==0.0.1) (2023.8.1)
# Requirement already satisfied: dask-jobqueue in /usr/local/lib/python3.10/dist-packages (from smac->up-ac==0.0.1) (0.8.2)
# Requirement already satisfied: emcee>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from smac->up-ac==0.0.1) (3.1.4)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from smac->up-ac==0.0.1) (2023.6.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from smac->up-ac==0.0.1) (6.0.1)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.10/dist-packages (from tarski->up-ac==0.0.1) (1.0.0)
# Requirement already satisfied: antlr4-python3-runtime==4.7.2 in /usr/local/lib/python3.10/dist-packages (from tarski->up-ac==0.0.1) (4.7.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from unified-planning->up-ac==0.0.1) (3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.1.2->smac->up-ac==0.0.1) (3.2.0)
# Requirement already satisfied: distributed>=2022.02.0 in /usr/local/lib/python3.10/dist-packages (from dask-jobqueue->smac->up-ac==0.0.1) (2023.8.1)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from dask[distributed]->smac->up-ac==0.0.1) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from dask[distributed]->smac->up-ac==0.0.1) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask[distributed]->smac->up-ac==0.0.1) (2023.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask[distributed]->smac->up-ac==0.0.1) (23.2)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask[distributed]->smac->up-ac==0.0.1) (1.4.1)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask[distributed]->smac->up-ac==0.0.1) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask[distributed]->smac->up-ac==0.0.1) (6.8.0)
# Requirement already satisfied: jinja2>=2.10.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.02.0->dask-jobqueue->smac->up-ac==0.0.1) (3.1.2)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.02.0->dask-jobqueue->smac->up-ac==0.0.1) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.02.0->dask-jobqueue->smac->up-ac==0.0.1) (1.0.7)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.02.0->dask-jobqueue->smac->up-ac==0.0.1) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.02.0->dask-jobqueue->smac->up-ac==0.0.1) (2.0.0)
# Requirement already satisfied: tornado>=6.0.4 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.02.0->dask-jobqueue->smac->up-ac==0.0.1) (6.3.2)
# Requirement already satisfied: urllib3>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.02.0->dask-jobqueue->smac->up-ac==0.0.1) (2.0.6)
# Requirement already satisfied: zict>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.02.0->dask-jobqueue->smac->up-ac==0.0.1) (3.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask[distributed]->smac->up-ac==0.0.1) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.10.3->distributed>=2022.02.0->dask-jobqueue->smac->up-ac==0.0.1) (2.1.3)
# Requirement already satisfied: unified-planning[enhsp] in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from unified-planning[enhsp]) (3.1.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from unified-planning[enhsp]) (3.1)
# Requirement already satisfied: up-enhsp==0.0.15 in /usr/local/lib/python3.10/dist-packages (from unified-planning[enhsp]) (0.0.15)

# %% [markdown]
# Now, we are ready to use the up-ac module.

# %% [markdown]
# ### Imports

# %%
import os
import up_ac
import unified_planning as up
import multiprocessing as mp
from unified_planning.io import PDDLReader

# %% [markdown]
# As we use SMAC to optimize our planner, we import the classes `SmacInterface` and `SmacConfigurator` from the up-ac module.

# %%
from up_ac.Smac_interface import SmacInterface
from up_ac.Smac_configurator import SmacConfigurator

# %% [markdown]
# ### Planner

# %% [markdown]
# We want to use `enhsp` to solve our problem instances, optimizing for both `runtime` and `quality` in seperate optimizations.

# %%
engine = ['enhsp']
metrics = ['runtime', 'quality']

# %% [markdown]
# ### Accessing Files
# For testing purposes, there are multiple files included within the up-ac module. Hence we set `path` to access the imported modules files.
# To enable the module access different files within itself, we change the current working directory to the installed python packages.

# %%
path = '/usr/local/lib/python3.10/dist-packages/up_ac'

os.chdir("/usr/local/lib/python3.10/dist-packages")

# %% [markdown]
# ### Problem representation
# In this example, we will generate plans for the following problem instances. The problem instance files are located within the up-ac module.

# %%
instances = [f'{path}/test_problems/depot/problem.pddl',
             f'{path}/test_problems/counters/problem.pddl',
             f'{path}/test_problems/citycar/problem.pddl',
             f'{path}/test_problems/sailing/problem.pddl',
             f'{path}/test_problems/safe_road/problem.pddl']

# %% [markdown]
# ###Initialization
# We initialize the generic Algorithm Configuration interface by calling it's respective class `SmacInterface` and reading in it's engine pieces. These are handed inside the up-ac package.

# %%
sgaci = SmacInterface()
sgaci.read_engine_pcs(engine, f'{path}/engine_pcs')

# %% [markdown]
# We initialize an empty dictionary `instance_features` and compute features for every testing instance respectively.

# %%
instance_features = {}
for instance in instances:
    instance_features[instance] \
        = sgaci.compute_instance_features(
            instance.rsplit('/', 1)[0] + '/domain.pddl',
            instance)
# Out:
# [WARNING][reader.py:78] Domain names as declared in domain and instance files do not coincide: "depot" vs " Depot"

# %% [markdown]
# We introduce `SAC` as our Smac Algorithm Configurator and save the `instances_features` from above in it. We then set both the training instances and testing instances to the included problem instances.
# Before we can use this Configurator, we need to set a scenario. This declares how we want our Configurator to behave.

# %%
SAC = SmacConfigurator()
SAC.get_instance_features(instance_features)
SAC.set_training_instance_set(instances)
SAC.set_test_instance_set(instances)

SAC.set_scenario(engine = engine[0],
                 param_space = sgaci.engine_param_spaces[engine[0]],
                 gaci = sgaci,
                 configuration_time=30,
                 n_trials=50,
                 min_budget=2,
                 max_budget=5,
                 crash_cost=0,
                 planner_timelimit=5,
                 n_workers=1,
                 instance_features = SAC.instance_features)
# Out:
# Setting instance features.
#
#
# Setting training instance set.
#
#
# Setting testing instance set.
#
#
# SMAC scenario is set.

# %% [markdown]
# The `default_config` is a set of parameters, but it might not perform very well.

# %%
default_config = sgaci.engine_param_spaces[engine[0]].get_default_configuration()

# %% [markdown]
# Since SMACs parallelization uses dask, we are required to pickle the feedback function. This is the reason for the necessity to pass the PDDLReader object. This is handled in the automated algorithm configurator internally.

# %%
reader = PDDLReader()

# %% [markdown]
# ### Simple Testing
# Let's start with a simple test, by creating a feedback function and letting it evaluate the 'default_config' on our first testing instance.
# To do so, we first need to set the scenario for our Configurator. As this function depends on a `metric`, we do this for both of the metrics we evaluate by.

# %%
SAC_fb_func_quality = SAC.get_feedback_function(gaci = sgaci,
                                                engine = engine[0],
                                                metric = "quality",
                                                mode = 'OneshotPlanner')

SAC_fb_func_quality(default_config, instances[0], seed = 42, reader=reader)
# Out:
# {'heuristic': 'hadd', 'search_algorithm': 'gbfs'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     lift(hoist1, crate0, pallet1, distributor0)
#     lift(hoist0, crate1, pallet0, depot0)
#     load(hoist0, crate1, truck1, depot0)
#     drive(truck1, depot0, distributor0)
#     load(hoist1, crate0, truck1, distributor0)
#     unload(hoist1, crate1, truck1, distributor0)
#     drive(truck1, distributor0, distributor1)
#     unload(hoist2, crate0, truck1, distributor1)
#     drop(hoist1, crate1, pallet1, distributor0)
#     drop(hoist2, crate0, pallet2, distributor1)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 70\nAibr Preprocessing\n|F|:40\n|X|:0\n|A|:90\n|P|:0\n|E|:0\nH1 Setup Time (msec): 19\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=11.0\n g(n)= 1.0 h(n)=10.0\n g(n)= 2.0 h(n)=9.0\n g(n)= 3.0 h(n)=8.0\n g(n)= 4.0 h(n)=7.0\n g(n)= 5.0 h(n)=5.0\n g(n)= 6.0 h(n)=4.0\n g(n)= 7.0 h(n)=3.0\n g(n)= 8.0 h(n)=2.0\n g(n)= 9.0 h(n)=1.0\n g(n)= 10.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (lift hoist1 crate0 pallet1 distributor0)\n1.0: (lift hoist0 crate1 pallet0 depot0)\n2.0: (load hoist0 crate1 truck1 depot0)\n3.0: (drive truck1 depot0 distributor0)\n4.0: (load hoist1 crate0 truck1 distributor0)\n5.0: (unload hoist1 crate1 truck1 distributor0)\n6.0: (drive truck1 distributor0 distributor1)\n7.0: (unload hoist2 crate0 truck1 distributor1)\n8.0: (drop hoist1 crate1 pallet1 distributor0)\n9.0: (drop hoist2 crate0 pallet2 distributor1)\n\nPlan-Length:10\nMetric (Search):10.0\nPlanning Time (msec): 603\nHeuristic Time (msec): 37\nSearch Time (msec): 109\nExpanded Nodes:11\nStates Evaluated:69\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:4\nNumber of Duplicates detected:16\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/depot/problem.pddl
# ** is 10.0
# -10.0

# %%
SAC_fb_func_runtime = SAC.get_feedback_function(gaci = sgaci,
                                                engine = engine[0],
                                                metric = "runtime",
                                                mode = 'OneshotPlanner')

SAC_fb_func_runtime(default_config, instances[0], seed = 42, reader=reader)
# Out:
# {'heuristic': 'hadd', 'search_algorithm': 'gbfs'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     lift(hoist1, crate0, pallet1, distributor0)
#     lift(hoist0, crate1, pallet0, depot0)
#     load(hoist0, crate1, truck1, depot0)
#     drive(truck1, depot0, distributor0)
#     load(hoist1, crate0, truck1, distributor0)
#     unload(hoist1, crate1, truck1, distributor0)
#     drive(truck1, distributor0, distributor1)
#     unload(hoist2, crate0, truck1, distributor1)
#     drop(hoist1, crate1, pallet1, distributor0)
#     drop(hoist2, crate0, pallet2, distributor1)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 51\nAibr Preprocessing\n|F|:40\n|X|:0\n|A|:90\n|P|:0\n|E|:0\nH1 Setup Time (msec): 9\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=11.0\n g(n)= 1.0 h(n)=10.0\n g(n)= 2.0 h(n)=9.0\n g(n)= 3.0 h(n)=8.0\n g(n)= 4.0 h(n)=7.0\n g(n)= 5.0 h(n)=5.0\n g(n)= 6.0 h(n)=4.0\n g(n)= 7.0 h(n)=3.0\n g(n)= 8.0 h(n)=2.0\n g(n)= 9.0 h(n)=1.0\n g(n)= 10.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (lift hoist1 crate0 pallet1 distributor0)\n1.0: (lift hoist0 crate1 pallet0 depot0)\n2.0: (load hoist0 crate1 truck1 depot0)\n3.0: (drive truck1 depot0 distributor0)\n4.0: (load hoist1 crate0 truck1 distributor0)\n5.0: (unload hoist1 crate1 truck1 distributor0)\n6.0: (drive truck1 distributor0 distributor1)\n7.0: (unload hoist2 crate0 truck1 distributor1)\n8.0: (drop hoist1 crate1 pallet1 distributor0)\n9.0: (drop hoist2 crate0 pallet2 distributor1)\n\nPlan-Length:10\nMetric (Search):10.0\nPlanning Time (msec): 366\nHeuristic Time (msec): 15\nSearch Time (msec): 48\nExpanded Nodes:11\nStates Evaluated:69\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:4\nNumber of Duplicates detected:16\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/depot/problem.pddl
# ** is 3.66
# 3.66

# %% [markdown]
# Before starting, we supress a repeating call of engine credits.

# %%
up.shortcuts.get_environment().credits_stream = None

# %% [markdown]
# ### Running the Smac Algorithm Configurator
#
# We initiate the SMAC Algorithm Configurator as we did above. We then run the optimization of our setup and save the best configuration as `incumbent`. After evaluating the performance of our optimized configuration we save it as a seperate file.

# %%
for metric in metrics:

    SAC.set_scenario(engine[0],
                     sgaci.engine_param_spaces[engine[0]],
                     sgaci,
                     configuration_time=30,
                     n_trials=50,
                     min_budget=2,
                     max_budget=5,
                     crash_cost=0,
                     planner_timelimit=5,
                     n_workers=1,
                     instance_features=SAC.instance_features)


    SAC_fb_func = SAC.get_feedback_function(sgaci, engine[0],
                                            metric, 'OneshotPlanner')


    # run algorithm configuration
    incumbent, _ = SAC.optimize(feedback_function=SAC_fb_func)

    # check configurations performance
    perf = SAC.evaluate(metric, engine[0], 'OneshotPlanner',
                            incumbent, sgaci, planner_timelimit=5)

    # save best configuration found
    SAC.save_config('.', incumbent, sgaci, engine[0])
# Out:
# SMAC scenario is set.
#
#
# Starting Parameter optimization
#
# [INFO][abstract_initial_design.py:95] Reducing the number of initial configurations from 20 to 12 (max_ratio == 0.25).
# [INFO][abstract_initial_design.py:147] Using -2 initial design configurations and 3 additional configurations.
# [INFO][abstract_intensifier.py:305] Using only one seed for deterministic scenario.
# {'heuristic': 'hadd', 'search_algorithm': 'gbfs'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 33\nAibr Preprocessing\n|F|:9\n|X|:0\n|A|:10\n|P|:0\n|E|:0\nH1 Setup Time (msec): 16\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=0.0\nProblem Solved\n\nFound Plan:\n\nPlan-Length:0\nMetric (Search):0.0\nPlanning Time (msec): 433\nHeuristic Time (msec): 0\nSearch Time (msec): 8\nExpanded Nodes:1\nStates Evaluated:0\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:0\nNumber of Duplicates detected:0\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/safe_road/problem.pddl
# ** is 4.33
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aaebd090>
# [INFO][abstract_intensifier.py:515] Added config 0eb7d5 as new incumbent because there are no incumbents yet.
# {'heuristic': 'hadd', 'search_algorithm': 'gbfs'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     go_south(b1)
#     go_south(b1)
#     go_south(b1)
#     go_south(b1)
#     go_south(b1)
#     go_south_west(b1)
#     save_person(b1, p0)
#     go_south(b1)
#     save_person(b1, p1)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 53\nAibr Preprocessing\n|F|:2\n|X|:4\n|A|:18\n|P|:0\n|E|:0\nH1 Setup Time (msec): 28\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=8.5\n g(n)= 1.0 h(n)=7.5\n g(n)= 2.0 h(n)=6.5\n g(n)= 3.0 h(n)=5.5\n g(n)= 4.0 h(n)=4.5\n g(n)= 5.0 h(n)=3.5\n g(n)= 6.0 h(n)=2.5\n g(n)= 7.0 h(n)=1.5\n g(n)= 8.0 h(n)=1.0\n g(n)= 9.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (go_south b1)\n1.0: (go_south b1)\n2.0: (go_south b1)\n3.0: (go_south b1)\n4.0: (go_south b1)\n5.0: (go_south_west b1)\n6.0: (save_person b1 p0)\n7.0: (go_south b1)\n8.0: (save_person b1 p1)\n\nPlan-Length:9\nMetric (Search):9.0\nPlanning Time (msec): 783\nHeuristic Time (msec): 29\nSearch Time (msec): 84\nExpanded Nodes:10\nStates Evaluated:134\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:0\nNumber of Duplicates detected:2\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/sailing/problem.pddl
# ** is 7.83
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aaebd5a0>
# {'heuristic': 'blind', 'search_algorithm': 'gbfs'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     go_south(b1)
#     go_south(b1)
#     go_south(b1)
#     go_south(b1)
#     go_south(b1)
#     go_south_west(b1)
#     save_person(b1, p0)
#     go_south(b1)
#     save_person(b1, p1)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 49\nAibr Preprocessing\n|F|:2\n|X|:4\n|A|:18\n|P|:0\n|E|:0\nH1 Setup Time (msec): 17\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=8.5\n g(n)= 1.0 h(n)=7.5\n g(n)= 2.0 h(n)=6.5\n g(n)= 3.0 h(n)=5.5\n g(n)= 4.0 h(n)=4.5\n g(n)= 5.0 h(n)=3.5\n g(n)= 6.0 h(n)=2.5\n g(n)= 7.0 h(n)=1.5\n g(n)= 8.0 h(n)=1.0\n g(n)= 9.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (go_south b1)\n1.0: (go_south b1)\n2.0: (go_south b1)\n3.0: (go_south b1)\n4.0: (go_south b1)\n5.0: (go_south_west b1)\n6.0: (save_person b1 p0)\n7.0: (go_south b1)\n8.0: (save_person b1 p1)\n\nPlan-Length:9\nMetric (Search):9.0\nPlanning Time (msec): 705\nHeuristic Time (msec): 41\nSearch Time (msec): 91\nExpanded Nodes:10\nStates Evaluated:134\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:0\nNumber of Duplicates detected:2\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/sailing/problem.pddl
# ** is 7.05
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aa9fc280>
# {'heuristic': 'blind', 'search_algorithm': 'gbfs'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 60\nAibr Preprocessing\n|F|:9\n|X|:0\n|A|:10\n|P|:0\n|E|:0\nH1 Setup Time (msec): 16\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=0.0\nProblem Solved\n\nFound Plan:\n\nPlan-Length:0\nMetric (Search):0.0\nPlanning Time (msec): 603\nHeuristic Time (msec): 0\nSearch Time (msec): 11\nExpanded Nodes:1\nStates Evaluated:0\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:0\nNumber of Duplicates detected:0\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/safe_road/problem.pddl
# ** is 6.03
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aa9fce50>
# {'heuristic': 'hadd', 'search_algorithm': 'gbfs'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     increment(c3)
#     increment(c3)
#     increment(c2)
#     increment(c3)
#     increment(c2)
#     increment(c1)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 39\nAibr Preprocessing\n|F|:0\n|X|:4\n|A|:8\n|P|:0\n|E|:0\nH1 Setup Time (msec): 13\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=3.0\n g(n)= 1.0 h(n)=2.0\n g(n)= 3.0 h(n)=1.0\n g(n)= 6.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (increment c3)\n1.0: (increment c3)\n2.0: (increment c2)\n3.0: (increment c3)\n4.0: (increment c2)\n5.0: (increment c1)\n\nPlan-Length:6\nMetric (Search):6.0\nPlanning Time (msec): 676\nHeuristic Time (msec): 13\nSearch Time (msec): 36\nExpanded Nodes:8\nStates Evaluated:28\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:0\nNumber of Duplicates detected:11\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/counters/problem.pddl
# ** is 6.76
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aa9fd5a0>
# {'heuristic': 'blind', 'search_algorithm': 'astar'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     go_south(b1)
#     go_south(b1)
#     go_south(b1)
#     go_south(b1)
#     go_south(b1)
#     go_south_west(b1)
#     save_person(b1, p0)
#     go_south(b1)
#     save_person(b1, p1)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 54\nAibr Preprocessing\n|F|:2\n|X|:4\n|A|:18\n|P|:0\n|E|:0\nH1 Setup Time (msec): 49\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=8.5\n g(n)= 1.0 h(n)=7.5\n g(n)= 2.0 h(n)=6.5\n g(n)= 3.0 h(n)=5.5\n g(n)= 4.0 h(n)=4.5\n g(n)= 5.0 h(n)=3.5\n g(n)= 6.0 h(n)=2.5\n g(n)= 7.0 h(n)=1.5\n g(n)= 8.0 h(n)=1.0\n g(n)= 9.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (go_south b1)\n1.0: (go_south b1)\n2.0: (go_south b1)\n3.0: (go_south b1)\n4.0: (go_south b1)\n5.0: (go_south_west b1)\n6.0: (save_person b1 p0)\n7.0: (go_south b1)\n8.0: (save_person b1 p1)\n\nPlan-Length:9\nMetric (Search):9.0\nPlanning Time (msec): 946\nHeuristic Time (msec): 123\nSearch Time (msec): 195\nExpanded Nodes:10\nStates Evaluated:134\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:0\nNumber of Duplicates detected:2\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/sailing/problem.pddl
# ** is 9.46
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aac22ef0>
# {'heuristic': 'blind', 'search_algorithm': 'astar'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 32\nAibr Preprocessing\n|F|:9\n|X|:0\n|A|:10\n|P|:0\n|E|:0\nH1 Setup Time (msec): 13\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=0.0\nProblem Solved\n\nFound Plan:\n\nPlan-Length:0\nMetric (Search):0.0\nPlanning Time (msec): 581\nHeuristic Time (msec): 0\nSearch Time (msec): 9\nExpanded Nodes:1\nStates Evaluated:0\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:0\nNumber of Duplicates detected:0\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/safe_road/problem.pddl
# ** is 5.81
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aaebd090>
# {'heuristic': 'blind', 'search_algorithm': 'astar'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     increment(c3)
#     increment(c3)
#     increment(c2)
#     increment(c3)
#     increment(c2)
#     increment(c1)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 24\nAibr Preprocessing\n|F|:0\n|X|:4\n|A|:8\n|P|:0\n|E|:0\nH1 Setup Time (msec): 6\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=3.0\n g(n)= 1.0 h(n)=2.0\n g(n)= 3.0 h(n)=1.0\n g(n)= 6.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (increment c3)\n1.0: (increment c3)\n2.0: (increment c2)\n3.0: (increment c3)\n4.0: (increment c2)\n5.0: (increment c1)\n\nPlan-Length:6\nMetric (Search):6.0\nPlanning Time (msec): 484\nHeuristic Time (msec): 7\nSearch Time (msec): 15\nExpanded Nodes:8\nStates Evaluated:28\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:0\nNumber of Duplicates detected:11\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/counters/problem.pddl
# ** is 4.84
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aaebd7e0>
# {'heuristic': 'hadd', 'search_algorithm': 'gbfs'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     lift(hoist1, crate0, pallet1, distributor0)
#     lift(hoist0, crate1, pallet0, depot0)
#     load(hoist0, crate1, truck1, depot0)
#     drive(truck1, depot0, distributor0)
#     load(hoist1, crate0, truck1, distributor0)
#     unload(hoist1, crate1, truck1, distributor0)
#     drive(truck1, distributor0, distributor1)
#     unload(hoist2, crate0, truck1, distributor1)
#     drop(hoist1, crate1, pallet1, distributor0)
#     drop(hoist2, crate0, pallet2, distributor1)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 70\nAibr Preprocessing\n|F|:40\n|X|:0\n|A|:90\n|P|:0\n|E|:0\nH1 Setup Time (msec): 10\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=11.0\n g(n)= 1.0 h(n)=10.0\n g(n)= 2.0 h(n)=9.0\n g(n)= 3.0 h(n)=8.0\n g(n)= 4.0 h(n)=7.0\n g(n)= 5.0 h(n)=5.0\n g(n)= 6.0 h(n)=4.0\n g(n)= 7.0 h(n)=3.0\n g(n)= 8.0 h(n)=2.0\n g(n)= 9.0 h(n)=1.0\n g(n)= 10.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (lift hoist1 crate0 pallet1 distributor0)\n1.0: (lift hoist0 crate1 pallet0 depot0)\n2.0: (load hoist0 crate1 truck1 depot0)\n3.0: (drive truck1 depot0 distributor0)\n4.0: (load hoist1 crate0 truck1 distributor0)\n5.0: (unload hoist1 crate1 truck1 distributor0)\n6.0: (drive truck1 distributor0 distributor1)\n7.0: (unload hoist2 crate0 truck1 distributor1)\n8.0: (drop hoist1 crate1 pallet1 distributor0)\n9.0: (drop hoist2 crate0 pallet2 distributor1)\n\nPlan-Length:10\nMetric (Search):10.0\nPlanning Time (msec): 386\nHeuristic Time (msec): 24\nSearch Time (msec): 42\nExpanded Nodes:11\nStates Evaluated:69\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:4\nNumber of Duplicates detected:16\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/depot/problem.pddl
# ** is 3.86
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aa9fd000>
# {'heuristic': 'hmax', 'search_algorithm': 'wastar'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     increment(c3)
#     increment(c3)
#     increment(c2)
#     increment(c3)
#     increment(c2)
#     increment(c1)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 15\nAibr Preprocessing\n|F|:0\n|X|:4\n|A|:8\n|P|:0\n|E|:0\nH1 Setup Time (msec): 8\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=3.0\n g(n)= 1.0 h(n)=2.0\n g(n)= 3.0 h(n)=1.0\n g(n)= 6.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (increment c3)\n1.0: (increment c3)\n2.0: (increment c2)\n3.0: (increment c3)\n4.0: (increment c2)\n5.0: (increment c1)\n\nPlan-Length:6\nMetric (Search):6.0\nPlanning Time (msec): 295\nHeuristic Time (msec): 8\nSearch Time (msec): 19\nExpanded Nodes:8\nStates Evaluated:28\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:0\nNumber of Duplicates detected:11\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/counters/problem.pddl
# ** is 2.95
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aa9fc430>
# {'heuristic': 'hmax', 'search_algorithm': 'wastar'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     lift(hoist1, crate0, pallet1, distributor0)
#     lift(hoist0, crate1, pallet0, depot0)
#     load(hoist0, crate1, truck1, depot0)
#     drive(truck1, depot0, distributor0)
#     load(hoist1, crate0, truck1, distributor0)
#     unload(hoist1, crate1, truck1, distributor0)
#     drive(truck1, distributor0, distributor1)
#     unload(hoist2, crate0, truck1, distributor1)
#     drop(hoist1, crate1, pallet1, distributor0)
#     drop(hoist2, crate0, pallet2, distributor1)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 49\nAibr Preprocessing\n|F|:40\n|X|:0\n|A|:90\n|P|:0\n|E|:0\nH1 Setup Time (msec): 24\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=11.0\n g(n)= 1.0 h(n)=10.0\n g(n)= 2.0 h(n)=9.0\n g(n)= 3.0 h(n)=8.0\n g(n)= 4.0 h(n)=7.0\n g(n)= 5.0 h(n)=5.0\n g(n)= 6.0 h(n)=4.0\n g(n)= 7.0 h(n)=3.0\n g(n)= 8.0 h(n)=2.0\n g(n)= 9.0 h(n)=1.0\n g(n)= 10.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (lift hoist1 crate0 pallet1 distributor0)\n1.0: (lift hoist0 crate1 pallet0 depot0)\n2.0: (load hoist0 crate1 truck1 depot0)\n3.0: (drive truck1 depot0 distributor0)\n4.0: (load hoist1 crate0 truck1 distributor0)\n5.0: (unload hoist1 crate1 truck1 distributor0)\n6.0: (drive truck1 distributor0 distributor1)\n7.0: (unload hoist2 crate0 truck1 distributor1)\n8.0: (drop hoist1 crate1 pallet1 distributor0)\n9.0: (drop hoist2 crate0 pallet2 distributor1)\n\nPlan-Length:10\nMetric (Search):10.0\nPlanning Time (msec): 383\nHeuristic Time (msec): 19\nSearch Time (msec): 46\nExpanded Nodes:11\nStates Evaluated:69\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:4\nNumber of Duplicates detected:16\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/depot/problem.pddl
# ** is 3.83
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59ab0092d0>
# {'heuristic': 'hmax', 'search_algorithm': 'wastar'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     go_south(b1)
#     go_south(b1)
#     go_south(b1)
#     go_south(b1)
#     go_south(b1)
#     go_south_west(b1)
#     save_person(b1, p0)
#     go_south(b1)
#     save_person(b1, p1)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 23\nAibr Preprocessing\n|F|:2\n|X|:4\n|A|:18\n|P|:0\n|E|:0\nH1 Setup Time (msec): 8\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=8.5\n g(n)= 1.0 h(n)=7.5\n g(n)= 2.0 h(n)=6.5\n g(n)= 3.0 h(n)=5.5\n g(n)= 4.0 h(n)=4.5\n g(n)= 5.0 h(n)=3.5\n g(n)= 6.0 h(n)=2.5\n g(n)= 7.0 h(n)=1.5\n g(n)= 8.0 h(n)=1.0\n g(n)= 9.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (go_south b1)\n1.0: (go_south b1)\n2.0: (go_south b1)\n3.0: (go_south b1)\n4.0: (go_south b1)\n5.0: (go_south_west b1)\n6.0: (save_person b1 p0)\n7.0: (go_south b1)\n8.0: (save_person b1 p1)\n\nPlan-Length:9\nMetric (Search):9.0\nPlanning Time (msec): 356\nHeuristic Time (msec): 37\nSearch Time (msec): 52\nExpanded Nodes:10\nStates Evaluated:134\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:0\nNumber of Duplicates detected:2\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/sailing/problem.pddl
# ** is 3.56
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aaebd090>
# {'heuristic': 'hmax', 'search_algorithm': 'wastar'}
# RESULTResult found.
#  status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 15\nAibr Preprocessing\n|F|:9\n|X|:0\n|A|:10\n|P|:0\n|E|:0\nH1 Setup Time (msec): 6\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=0.0\nProblem Solved\n\nFound Plan:\n\nPlan-Length:0\nMetric (Search):0.0\nPlanning Time (msec): 233\nHeuristic Time (msec): 0\nSearch Time (msec): 4\nExpanded Nodes:1\nStates Evaluated:0\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:0\nNumber of Duplicates detected:0\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/safe_road/problem.pddl
# ** is 2.33
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aaebc820>
# [INFO][abstract_intensifier.py:590] Added config 61837d and rejected config 0eb7d5 as incumbent because it is not better than the incumbents on 4 instances:
# {'heuristic': 'hmax', 'search_algorithm': 'wastar'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     build_straight_oneway(junction1-0, junction2-0, road1)
#     build_straight_oneway(junction0-0, junction1-0, road3)
#     build_diagonal_oneway(junction0-1, junction1-0, road2)
#     build_straight_oneway(junction1-1, junction0-1, road0)
#     car_start(junction0-1, car1, garage1)
#     move_car_in_road(junction0-1, junction1-0, car1, road2)
#     move_car_out_road(junction0-1, junction1-0, car1, road2)
#     move_car_in_road(junction1-0, junction2-0, car1, road1)
#     move_car_out_road(junction1-0, junction2-0, car1, road1)
#     car_start(junction0-0, car0, garage0)
#     move_car_in_road(junction0-0, junction1-0, car0, road3)
#     move_car_out_road(junction0-0, junction1-0, car0, road3)
#     move_car_in_road(junction1-0, junction2-0, car0, road1)
#     car_arrived(junction2-0, car1)
#     move_car_out_road(junction1-0, junction2-0, car0, road1)
#     build_straight_oneway(junction2-1, junction1-1, road4)
#     car_arrived(junction2-0, car0)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 142\nAibr Preprocessing\n|F|:262\n|X|:0\n|A|:1220\n|P|:0\n|E|:0\nH1 Setup Time (msec): 62\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=164.0\n g(n)= 20.0 h(n)=64.0\n g(n)= 40.0 h(n)=36.0\n g(n)= 70.0 h(n)=8.0\n g(n)= 91.0 h(n)=7.0\n g(n)= 92.0 h(n)=6.0\n g(n)= 93.0 h(n)=5.0\n g(n)= 94.0 h(n)=4.0\n g(n)= 95.0 h(n)=3.0\n g(n)= 96.0 h(n)=2.0\n g(n)= 97.0 h(n)=1.0\n g(n)= 98.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (build_straight_oneway junction1_0 junction2_0 road1)\n1.0: (build_straight_oneway junction0_0 junction1_0 road3)\n2.0: (build_diagonal_oneway junction0_1 junction1_0 road2)\n3.0: (build_straight_oneway junction1_1 junction0_1 road0)\n4.0: (car_start junction0_1 car1 garage1)\n5.0: (move_car_in_road junction0_1 junction1_0 car1 road2)\n6.0: (move_car_out_road junction0_1 junction1_0 car1 road2)\n7.0: (move_car_in_road junction1_0 junction2_0 car1 road1)\n8.0: (move_car_out_road junction1_0 junction2_0 car1 road1)\n9.0: (car_start junction0_0 car0 garage0)\n10.0: (move_car_in_road junction0_0 junction1_0 car0 road3)\n11.0: (move_car_out_road junction0_0 junction1_0 car0 road3)\n12.0: (move_car_in_road junction1_0 junction2_0 car0 road1)\n13.0: (car_arrived junction2_0 car1)\n14.0: (move_car_out_road junction1_0 junction2_0 car0 road1)\n15.0: (build_straight_oneway junction2_1 junction1_1 road4)\n16.0: (car_arrived junction2_0 car0)\n\nPlan-Length:17\nMetric (Search):118.0\nPlanning Time (msec): 1991\nHeuristic Time (msec): 921\nSearch Time (msec): 1095\nExpanded Nodes:127\nStates Evaluated:2222\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:4\nNumber of Duplicates detected:353\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/citycar/problem.pddl
# ** is 19.91
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aa9fd480>
# {'heuristic': 'hadd', 'search_algorithm': 'wastar'}
# RESULT[LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 162\nAibr Preprocessing\n|F|:262\n|X|:0\n|A|:1220\n|P|:0\n|E|:0\nH1 Setup Time (msec): 88\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=164.0\n g(n)= 20.0 h(n)=64.0\n g(n)= 40.0 h(n)=36.0\n g(n)= 70.0 h(n)=8.0\n g(n)= 91.0 h(n)=7.0\n g(n)= 92.0 h(n)=6.0\n g(n)= 93.0 h(n)=5.0\n g(n)= 94.0 h(n)=4.0\n g(n)= 95.0 h(n)=3.0\n g(n)= 96.0 h(n)=2.0\n g(n)= 97.0 h(n)=1.0\n g(n)= 98.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (build_straight_oneway junction1_0 junction2_0 road1)\n1.0: (build_straight_oneway junction0_0 junction1_0 road3)\n2.0: (build_diagonal_oneway junction0_1 junction1_0 road2)\n3.0: (build_straight_oneway junction1_1 junction0_1 road0)\n4.0: (car_start junction0_1 car1 garage1)\n5.0: (move_car_in_road junction0_1 junction1_0 car1 road2)\n6.0: (move_car_out_road junction0_1 junction1_0 car1 road2)\n7.0: (move_car_in_road junction1_0 junction2_0 car1 road1)\n8.0: (move_car_out_road junction1_0 junction2_0 car1 road1)\n9.0: (car_start junction0_0 car0 garage0)\n10.0: (move_car_in_road junction0_0 junction1_0 car0 road3)\n11.0: (move_car_out_road junction0_0 junction1_0 car0 road3)\n12.0: (move_car_in_road junction1_0 junction2_0 car0 road1)\n13.0: (car_arrived junction2_0 car1)\n14.0: (move_car_out_road junction1_0 junction2_0 car0 road1)\n15.0: (build_straight_oneway junction2_1 junction1_1 road4)\n16.0: (car_arrived junction2_0 car0)\n\nPlan-Length:17\nMetric (Search):118.0\nPlanning Time (msec): 1981\nHeuristic Time (msec): 971\nSearch Time (msec): 1137\nExpanded Nodes:127\nStates Evaluated:2222\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:4\nNumber of Duplicates detected:353\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')] status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     build_straight_oneway(junction1-0, junction2-0, road1)
#     build_straight_oneway(junction0-0, junction1-0, road3)
#     build_diagonal_oneway(junction0-1, junction1-0, road2)
#     build_straight_oneway(junction1-1, junction0-1, road0)
#     car_start(junction0-1, car1, garage1)
#     move_car_in_road(junction0-1, junction1-0, car1, road2)
#     move_car_out_road(junction0-1, junction1-0, car1, road2)
#     move_car_in_road(junction1-0, junction2-0, car1, road1)
#     move_car_out_road(junction1-0, junction2-0, car1, road1)
#     car_start(junction0-0, car0, garage0)
#     move_car_in_road(junction0-0, junction1-0, car0, road3)
#     move_car_out_road(junction0-0, junction1-0, car0, road3)
#     move_car_in_road(junction1-0, junction2-0, car0, road1)
#     car_arrived(junction2-0, car1)
#     move_car_out_road(junction1-0, junction2-0, car0, road1)
#     build_straight_oneway(junction2-1, junction1-1, road4)
#     car_arrived(junction2-0, car0)
#
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/citycar/problem.pddl
# ** is 19.81
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aa9fd750>
# {'heuristic': 'hadd', 'search_algorithm': 'wastar'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     go_south(b1)
#     go_south(b1)
#     go_south(b1)
#     go_south(b1)
#     go_south(b1)
#     go_south_west(b1)
#     save_person(b1, p0)
#     go_south(b1)
#     save_person(b1, p1)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 23\nAibr Preprocessing\n|F|:2\n|X|:4\n|A|:18\n|P|:0\n|E|:0\nH1 Setup Time (msec): 7\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=8.5\n g(n)= 1.0 h(n)=7.5\n g(n)= 2.0 h(n)=6.5\n g(n)= 3.0 h(n)=5.5\n g(n)= 4.0 h(n)=4.5\n g(n)= 5.0 h(n)=3.5\n g(n)= 6.0 h(n)=2.5\n g(n)= 7.0 h(n)=1.5\n g(n)= 8.0 h(n)=1.0\n g(n)= 9.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (go_south b1)\n1.0: (go_south b1)\n2.0: (go_south b1)\n3.0: (go_south b1)\n4.0: (go_south b1)\n5.0: (go_south_west b1)\n6.0: (save_person b1 p0)\n7.0: (go_south b1)\n8.0: (save_person b1 p1)\n\nPlan-Length:9\nMetric (Search):9.0\nPlanning Time (msec): 314\nHeuristic Time (msec): 25\nSearch Time (msec): 41\nExpanded Nodes:10\nStates Evaluated:134\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:0\nNumber of Duplicates detected:2\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/sailing/problem.pddl
# ** is 3.14
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aaebe680>
# {'heuristic': 'hadd', 'search_algorithm': 'wastar'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     increment(c3)
#     increment(c3)
#     increment(c2)
#     increment(c3)
#     increment(c2)
#     increment(c1)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 12\nAibr Preprocessing\n|F|:0\n|X|:4\n|A|:8\n|P|:0\n|E|:0\nH1 Setup Time (msec): 7\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=3.0\n g(n)= 1.0 h(n)=2.0\n g(n)= 3.0 h(n)=1.0\n g(n)= 6.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (increment c3)\n1.0: (increment c3)\n2.0: (increment c2)\n3.0: (increment c3)\n4.0: (increment c2)\n5.0: (increment c1)\n\nPlan-Length:6\nMetric (Search):6.0\nPlanning Time (msec): 275\nHeuristic Time (msec): 5\nSearch Time (msec): 15\nExpanded Nodes:8\nStates Evaluated:28\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:0\nNumber of Duplicates detected:11\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/counters/problem.pddl
# ** is 2.75
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59ab0095a0>
# {'heuristic': 'hadd', 'search_algorithm': 'wastar'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 19\nAibr Preprocessing\n|F|:9\n|X|:0\n|A|:10\n|P|:0\n|E|:0\nH1 Setup Time (msec): 8\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=0.0\nProblem Solved\n\nFound Plan:\n\nPlan-Length:0\nMetric (Search):0.0\nPlanning Time (msec): 226\nHeuristic Time (msec): 0\nSearch Time (msec): 5\nExpanded Nodes:1\nStates Evaluated:0\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:0\nNumber of Duplicates detected:0\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/safe_road/problem.pddl
# ** is 2.26
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aac22d40>
# {'heuristic': 'hadd', 'search_algorithm': 'wastar'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     lift(hoist1, crate0, pallet1, distributor0)
#     lift(hoist0, crate1, pallet0, depot0)
#     load(hoist0, crate1, truck1, depot0)
#     drive(truck1, depot0, distributor0)
#     load(hoist1, crate0, truck1, distributor0)
#     unload(hoist1, crate1, truck1, distributor0)
#     drive(truck1, distributor0, distributor1)
#     unload(hoist2, crate0, truck1, distributor1)
#     drop(hoist1, crate1, pallet1, distributor0)
#     drop(hoist2, crate0, pallet2, distributor1)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 102\nAibr Preprocessing\n|F|:40\n|X|:0\n|A|:90\n|P|:0\n|E|:0\nH1 Setup Time (msec): 22\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=11.0\n g(n)= 1.0 h(n)=10.0\n g(n)= 2.0 h(n)=9.0\n g(n)= 3.0 h(n)=8.0\n g(n)= 4.0 h(n)=7.0\n g(n)= 5.0 h(n)=5.0\n g(n)= 6.0 h(n)=4.0\n g(n)= 7.0 h(n)=3.0\n g(n)= 8.0 h(n)=2.0\n g(n)= 9.0 h(n)=1.0\n g(n)= 10.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (lift hoist1 crate0 pallet1 distributor0)\n1.0: (lift hoist0 crate1 pallet0 depot0)\n2.0: (load hoist0 crate1 truck1 depot0)\n3.0: (drive truck1 depot0 distributor0)\n4.0: (load hoist1 crate0 truck1 distributor0)\n5.0: (unload hoist1 crate1 truck1 distributor0)\n6.0: (drive truck1 distributor0 distributor1)\n7.0: (unload hoist2 crate0 truck1 distributor1)\n8.0: (drop hoist1 crate1 pallet1 distributor0)\n9.0: (drop hoist2 crate0 pallet2 distributor1)\n\nPlan-Length:10\nMetric (Search):10.0\nPlanning Time (msec): 723\nHeuristic Time (msec): 39\nSearch Time (msec): 102\nExpanded Nodes:11\nStates Evaluated:69\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:4\nNumber of Duplicates detected:16\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/depot/problem.pddl
# ** is 7.23
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aa9fd7e0>
# {'heuristic': 'blind', 'search_algorithm': 'wastar'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 32\nAibr Preprocessing\n|F|:9\n|X|:0\n|A|:10\n|P|:0\n|E|:0\nH1 Setup Time (msec): 16\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=0.0\nProblem Solved\n\nFound Plan:\n\nPlan-Length:0\nMetric (Search):0.0\nPlanning Time (msec): 406\nHeuristic Time (msec): 0\nSearch Time (msec): 7\nExpanded Nodes:1\nStates Evaluated:0\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:0\nNumber of Duplicates detected:0\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/safe_road/problem.pddl
# ** is 4.06
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aa9fcca0>
# {'heuristic': 'blind', 'search_algorithm': 'wastar'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     lift(hoist1, crate0, pallet1, distributor0)
#     lift(hoist0, crate1, pallet0, depot0)
#     load(hoist0, crate1, truck1, depot0)
#     drive(truck1, depot0, distributor0)
#     load(hoist1, crate0, truck1, distributor0)
#     unload(hoist1, crate1, truck1, distributor0)
#     drive(truck1, distributor0, distributor1)
#     unload(hoist2, crate0, truck1, distributor1)
#     drop(hoist1, crate1, pallet1, distributor0)
#     drop(hoist2, crate0, pallet2, distributor1)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 72\nAibr Preprocessing\n|F|:40\n|X|:0\n|A|:90\n|P|:0\n|E|:0\nH1 Setup Time (msec): 9\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=11.0\n g(n)= 1.0 h(n)=10.0\n g(n)= 2.0 h(n)=9.0\n g(n)= 3.0 h(n)=8.0\n g(n)= 4.0 h(n)=7.0\n g(n)= 5.0 h(n)=5.0\n g(n)= 6.0 h(n)=4.0\n g(n)= 7.0 h(n)=3.0\n g(n)= 8.0 h(n)=2.0\n g(n)= 9.0 h(n)=1.0\n g(n)= 10.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (lift hoist1 crate0 pallet1 distributor0)\n1.0: (lift hoist0 crate1 pallet0 depot0)\n2.0: (load hoist0 crate1 truck1 depot0)\n3.0: (drive truck1 depot0 distributor0)\n4.0: (load hoist1 crate0 truck1 distributor0)\n5.0: (unload hoist1 crate1 truck1 distributor0)\n6.0: (drive truck1 distributor0 distributor1)\n7.0: (unload hoist2 crate0 truck1 distributor1)\n8.0: (drop hoist1 crate1 pallet1 distributor0)\n9.0: (drop hoist2 crate0 pallet2 distributor1)\n\nPlan-Length:10\nMetric (Search):10.0\nPlanning Time (msec): 496\nHeuristic Time (msec): 23\nSearch Time (msec): 51\nExpanded Nodes:11\nStates Evaluated:69\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:4\nNumber of Duplicates detected:16\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/depot/problem.pddl
# ** is 4.96
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59ab00b2e0>
# {'heuristic': 'blind', 'search_algorithm': 'wastar'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     go_south(b1)
#     go_south(b1)
#     go_south(b1)
#     go_south(b1)
#     go_south(b1)
#     go_south_west(b1)
#     save_person(b1, p0)
#     go_south(b1)
#     save_person(b1, p1)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 23\nAibr Preprocessing\n|F|:2\n|X|:4\n|A|:18\n|P|:0\n|E|:0\nH1 Setup Time (msec): 7\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=8.5\n g(n)= 1.0 h(n)=7.5\n g(n)= 2.0 h(n)=6.5\n g(n)= 3.0 h(n)=5.5\n g(n)= 4.0 h(n)=4.5\n g(n)= 5.0 h(n)=3.5\n g(n)= 6.0 h(n)=2.5\n g(n)= 7.0 h(n)=1.5\n g(n)= 8.0 h(n)=1.0\n g(n)= 9.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (go_south b1)\n1.0: (go_south b1)\n2.0: (go_south b1)\n3.0: (go_south b1)\n4.0: (go_south b1)\n5.0: (go_south_west b1)\n6.0: (save_person b1 p0)\n7.0: (go_south b1)\n8.0: (save_person b1 p1)\n\nPlan-Length:9\nMetric (Search):9.0\nPlanning Time (msec): 317\nHeuristic Time (msec): 25\nSearch Time (msec): 42\nExpanded Nodes:10\nStates Evaluated:134\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:0\nNumber of Duplicates detected:2\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/sailing/problem.pddl
# ** is 3.17
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aaebdfc0>
# {'heuristic': 'blind', 'search_algorithm': 'wastar'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     build_straight_oneway(junction1-0, junction2-0, road1)
#     build_straight_oneway(junction0-0, junction1-0, road3)
#     build_diagonal_oneway(junction0-1, junction1-0, road2)
#     build_straight_oneway(junction1-1, junction0-1, road0)
#     car_start(junction0-1, car1, garage1)
#     move_car_in_road(junction0-1, junction1-0, car1, road2)
#     move_car_out_road(junction0-1, junction1-0, car1, road2)
#     move_car_in_road(junction1-0, junction2-0, car1, road1)
#     move_car_out_road(junction1-0, junction2-0, car1, road1)
#     car_start(junction0-0, car0, garage0)
#     move_car_in_road(junction0-0, junction1-0, car0, road3)
#     move_car_out_road(junction0-0, junction1-0, car0, road3)
#     move_car_in_road(junction1-0, junction2-0, car0, road1)
#     car_arrived(junction2-0, car1)
#     move_car_out_road(junction1-0, junction2-0, car0, road1)
#     build_straight_oneway(junction2-1, junction1-1, road4)
#     car_arrived(junction2-0, car0)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 124\nAibr Preprocessing\n|F|:262\n|X|:0\n|A|:1220\n|P|:0\n|E|:0\nH1 Setup Time (msec): 77\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=164.0\n g(n)= 20.0 h(n)=64.0\n g(n)= 40.0 h(n)=36.0\n g(n)= 70.0 h(n)=8.0\n g(n)= 91.0 h(n)=7.0\n g(n)= 92.0 h(n)=6.0\n g(n)= 93.0 h(n)=5.0\n g(n)= 94.0 h(n)=4.0\n g(n)= 95.0 h(n)=3.0\n g(n)= 96.0 h(n)=2.0\n g(n)= 97.0 h(n)=1.0\n g(n)= 98.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (build_straight_oneway junction1_0 junction2_0 road1)\n1.0: (build_straight_oneway junction0_0 junction1_0 road3)\n2.0: (build_diagonal_oneway junction0_1 junction1_0 road2)\n3.0: (build_straight_oneway junction1_1 junction0_1 road0)\n4.0: (car_start junction0_1 car1 garage1)\n5.0: (move_car_in_road junction0_1 junction1_0 car1 road2)\n6.0: (move_car_out_road junction0_1 junction1_0 car1 road2)\n7.0: (move_car_in_road junction1_0 junction2_0 car1 road1)\n8.0: (move_car_out_road junction1_0 junction2_0 car1 road1)\n9.0: (car_start junction0_0 car0 garage0)\n10.0: (move_car_in_road junction0_0 junction1_0 car0 road3)\n11.0: (move_car_out_road junction0_0 junction1_0 car0 road3)\n12.0: (move_car_in_road junction1_0 junction2_0 car0 road1)\n13.0: (car_arrived junction2_0 car1)\n14.0: (move_car_out_road junction1_0 junction2_0 car0 road1)\n15.0: (build_straight_oneway junction2_1 junction1_1 road4)\n16.0: (car_arrived junction2_0 car0)\n\nPlan-Length:17\nMetric (Search):118.0\nPlanning Time (msec): 1854\nHeuristic Time (msec): 810\nSearch Time (msec): 1050\nExpanded Nodes:127\nStates Evaluated:2222\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:4\nNumber of Duplicates detected:353\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/citycar/problem.pddl
# ** is 18.54
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aa9fda20>
# {'heuristic': 'blind', 'search_algorithm': 'wastar'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     increment(c3)
#     increment(c3)
#     increment(c2)
#     increment(c3)
#     increment(c2)
#     increment(c1)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 13\nAibr Preprocessing\n|F|:0\n|X|:4\n|A|:8\n|P|:0\n|E|:0\nH1 Setup Time (msec): 10\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=3.0\n g(n)= 1.0 h(n)=2.0\n g(n)= 3.0 h(n)=1.0\n g(n)= 6.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (increment c3)\n1.0: (increment c3)\n2.0: (increment c2)\n3.0: (increment c3)\n4.0: (increment c2)\n5.0: (increment c1)\n\nPlan-Length:6\nMetric (Search):6.0\nPlanning Time (msec): 293\nHeuristic Time (msec): 7\nSearch Time (msec): 18\nExpanded Nodes:8\nStates Evaluated:28\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:0\nNumber of Duplicates detected:11\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/counters/problem.pddl
# ** is 2.93
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aa9fc8b0>
# {'heuristic': 'hmax', 'search_algorithm': 'astar'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     build_straight_oneway(junction1-0, junction2-0, road1)
#     build_straight_oneway(junction0-0, junction1-0, road3)
#     build_diagonal_oneway(junction0-1, junction1-0, road2)
#     build_straight_oneway(junction1-1, junction0-1, road0)
#     car_start(junction0-1, car1, garage1)
#     move_car_in_road(junction0-1, junction1-0, car1, road2)
#     move_car_out_road(junction0-1, junction1-0, car1, road2)
#     move_car_in_road(junction1-0, junction2-0, car1, road1)
#     move_car_out_road(junction1-0, junction2-0, car1, road1)
#     car_start(junction0-0, car0, garage0)
#     move_car_in_road(junction0-0, junction1-0, car0, road3)
#     move_car_out_road(junction0-0, junction1-0, car0, road3)
#     move_car_in_road(junction1-0, junction2-0, car0, road1)
#     car_arrived(junction2-0, car1)
#     move_car_out_road(junction1-0, junction2-0, car0, road1)
#     build_straight_oneway(junction2-1, junction1-1, road4)
#     car_arrived(junction2-0, car0)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 118\nAibr Preprocessing\n|F|:262\n|X|:0\n|A|:1220\n|P|:0\n|E|:0\nH1 Setup Time (msec): 71\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=164.0\n g(n)= 20.0 h(n)=64.0\n g(n)= 40.0 h(n)=36.0\n g(n)= 70.0 h(n)=8.0\n g(n)= 91.0 h(n)=7.0\n g(n)= 92.0 h(n)=6.0\n g(n)= 93.0 h(n)=5.0\n g(n)= 94.0 h(n)=4.0\n g(n)= 95.0 h(n)=3.0\n g(n)= 96.0 h(n)=2.0\n g(n)= 97.0 h(n)=1.0\n g(n)= 98.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (build_straight_oneway junction1_0 junction2_0 road1)\n1.0: (build_straight_oneway junction0_0 junction1_0 road3)\n2.0: (build_diagonal_oneway junction0_1 junction1_0 road2)\n3.0: (build_straight_oneway junction1_1 junction0_1 road0)\n4.0: (car_start junction0_1 car1 garage1)\n5.0: (move_car_in_road junction0_1 junction1_0 car1 road2)\n6.0: (move_car_out_road junction0_1 junction1_0 car1 road2)\n7.0: (move_car_in_road junction1_0 junction2_0 car1 road1)\n8.0: (move_car_out_road junction1_0 junction2_0 car1 road1)\n9.0: (car_start junction0_0 car0 garage0)\n10.0: (move_car_in_road junction0_0 junction1_0 car0 road3)\n11.0: (move_car_out_road junction0_0 junction1_0 car0 road3)\n12.0: (move_car_in_road junction1_0 junction2_0 car0 road1)\n13.0: (car_arrived junction2_0 car1)\n14.0: (move_car_out_road junction1_0 junction2_0 car0 road1)\n15.0: (build_straight_oneway junction2_1 junction1_1 road4)\n16.0: (car_arrived junction2_0 car0)\n\nPlan-Length:17\nMetric (Search):118.0\nPlanning Time (msec): 1862\nHeuristic Time (msec): 819\nSearch Time (msec): 971\nExpanded Nodes:127\nStates Evaluated:2222\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:4\nNumber of Duplicates detected:353\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/citycar/problem.pddl
# ** is 18.62
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aa9fdc60>
# {'heuristic': 'hmax', 'search_algorithm': 'astar'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 14\nAibr Preprocessing\n|F|:9\n|X|:0\n|A|:10\n|P|:0\n|E|:0\nH1 Setup Time (msec): 9\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=0.0\nProblem Solved\n\nFound Plan:\n\nPlan-Length:0\nMetric (Search):0.0\nPlanning Time (msec): 218\nHeuristic Time (msec): 0\nSearch Time (msec): 5\nExpanded Nodes:1\nStates Evaluated:0\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:0\nNumber of Duplicates detected:0\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/safe_road/problem.pddl
# ** is 2.18
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aaebcf70>
# {'heuristic': 'hmax', 'search_algorithm': 'astar'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     lift(hoist1, crate0, pallet1, distributor0)
#     lift(hoist0, crate1, pallet0, depot0)
#     load(hoist0, crate1, truck1, depot0)
#     drive(truck1, depot0, distributor0)
#     load(hoist1, crate0, truck1, distributor0)
#     unload(hoist1, crate1, truck1, distributor0)
#     drive(truck1, distributor0, distributor1)
#     unload(hoist2, crate0, truck1, distributor1)
#     drop(hoist1, crate1, pallet1, distributor0)
#     drop(hoist2, crate0, pallet2, distributor1)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 49\nAibr Preprocessing\n|F|:40\n|X|:0\n|A|:90\n|P|:0\n|E|:0\nH1 Setup Time (msec): 10\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=11.0\n g(n)= 1.0 h(n)=10.0\n g(n)= 2.0 h(n)=9.0\n g(n)= 3.0 h(n)=8.0\n g(n)= 4.0 h(n)=7.0\n g(n)= 5.0 h(n)=5.0\n g(n)= 6.0 h(n)=4.0\n g(n)= 7.0 h(n)=3.0\n g(n)= 8.0 h(n)=2.0\n g(n)= 9.0 h(n)=1.0\n g(n)= 10.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (lift hoist1 crate0 pallet1 distributor0)\n1.0: (lift hoist0 crate1 pallet0 depot0)\n2.0: (load hoist0 crate1 truck1 depot0)\n3.0: (drive truck1 depot0 distributor0)\n4.0: (load hoist1 crate0 truck1 distributor0)\n5.0: (unload hoist1 crate1 truck1 distributor0)\n6.0: (drive truck1 distributor0 distributor1)\n7.0: (unload hoist2 crate0 truck1 distributor1)\n8.0: (drop hoist1 crate1 pallet1 distributor0)\n9.0: (drop hoist2 crate0 pallet2 distributor1)\n\nPlan-Length:10\nMetric (Search):10.0\nPlanning Time (msec): 379\nHeuristic Time (msec): 19\nSearch Time (msec): 46\nExpanded Nodes:11\nStates Evaluated:69\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:4\nNumber of Duplicates detected:16\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/depot/problem.pddl
# ** is 3.79
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aac23ac0>
# {'heuristic': 'hmax', 'search_algorithm': 'astar'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     increment(c3)
#     increment(c3)
#     increment(c2)
#     increment(c3)
#     increment(c2)
#     increment(c1)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 12\nAibr Preprocessing\n|F|:0\n|X|:4\n|A|:8\n|P|:0\n|E|:0\nH1 Setup Time (msec): 7\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=3.0\n g(n)= 1.0 h(n)=2.0\n g(n)= 3.0 h(n)=1.0\n g(n)= 6.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (increment c3)\n1.0: (increment c3)\n2.0: (increment c2)\n3.0: (increment c3)\n4.0: (increment c2)\n5.0: (increment c1)\n\nPlan-Length:6\nMetric (Search):6.0\nPlanning Time (msec): 281\nHeuristic Time (msec): 4\nSearch Time (msec): 15\nExpanded Nodes:8\nStates Evaluated:28\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:0\nNumber of Duplicates detected:11\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/counters/problem.pddl
# ** is 2.81
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59ab29c430>
# ...
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/citycar/problem.pddl
# ** is 118.0
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aac23370>
# {'heuristic': 'hmax', 'search_algorithm': 'astar'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 17\nAibr Preprocessing\n|F|:9\n|X|:0\n|A|:10\n|P|:0\n|E|:0\nH1 Setup Time (msec): 8\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=0.0\nProblem Solved\n\nFound Plan:\n\nPlan-Length:0\nMetric (Search):0.0\nPlanning Time (msec): 263\nHeuristic Time (msec): 0\nSearch Time (msec): 4\nExpanded Nodes:1\nStates Evaluated:0\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:0\nNumber of Duplicates detected:0\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/safe_road/problem.pddl
# ** is 0.0
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59ab009870>
# {'heuristic': 'hmax', 'search_algorithm': 'astar'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     lift(hoist1, crate0, pallet1, distributor0)
#     lift(hoist0, crate1, pallet0, depot0)
#     load(hoist0, crate1, truck1, depot0)
#     drive(truck1, depot0, distributor0)
#     load(hoist1, crate0, truck1, distributor0)
#     unload(hoist1, crate1, truck1, distributor0)
#     drive(truck1, distributor0, distributor1)
#     unload(hoist2, crate0, truck1, distributor1)
#     drop(hoist1, crate1, pallet1, distributor0)
#     drop(hoist2, crate0, pallet2, distributor1)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 95\nAibr Preprocessing\n|F|:40\n|X|:0\n|A|:90\n|P|:0\n|E|:0\nH1 Setup Time (msec): 25\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=11.0\n g(n)= 1.0 h(n)=10.0\n g(n)= 2.0 h(n)=9.0\n g(n)= 3.0 h(n)=8.0\n g(n)= 4.0 h(n)=7.0\n g(n)= 5.0 h(n)=5.0\n g(n)= 6.0 h(n)=4.0\n g(n)= 7.0 h(n)=3.0\n g(n)= 8.0 h(n)=2.0\n g(n)= 9.0 h(n)=1.0\n g(n)= 10.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (lift hoist1 crate0 pallet1 distributor0)\n1.0: (lift hoist0 crate1 pallet0 depot0)\n2.0: (load hoist0 crate1 truck1 depot0)\n3.0: (drive truck1 depot0 distributor0)\n4.0: (load hoist1 crate0 truck1 distributor0)\n5.0: (unload hoist1 crate1 truck1 distributor0)\n6.0: (drive truck1 distributor0 distributor1)\n7.0: (unload hoist2 crate0 truck1 distributor1)\n8.0: (drop hoist1 crate1 pallet1 distributor0)\n9.0: (drop hoist2 crate0 pallet2 distributor1)\n\nPlan-Length:10\nMetric (Search):10.0\nPlanning Time (msec): 505\nHeuristic Time (msec): 21\nSearch Time (msec): 43\nExpanded Nodes:11\nStates Evaluated:69\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:4\nNumber of Duplicates detected:16\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/depot/problem.pddl
# ** is 10.0
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aa9fef80>
# {'heuristic': 'hmax', 'search_algorithm': 'astar'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     increment(c3)
#     increment(c3)
#     increment(c2)
#     increment(c3)
#     increment(c2)
#     increment(c1)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 15\nAibr Preprocessing\n|F|:0\n|X|:4\n|A|:8\n|P|:0\n|E|:0\nH1 Setup Time (msec): 9\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=3.0\n g(n)= 1.0 h(n)=2.0\n g(n)= 3.0 h(n)=1.0\n g(n)= 6.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (increment c3)\n1.0: (increment c3)\n2.0: (increment c2)\n3.0: (increment c3)\n4.0: (increment c2)\n5.0: (increment c1)\n\nPlan-Length:6\nMetric (Search):6.0\nPlanning Time (msec): 327\nHeuristic Time (msec): 6\nSearch Time (msec): 20\nExpanded Nodes:8\nStates Evaluated:28\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:0\nNumber of Duplicates detected:11\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/counters/problem.pddl
# ** is 6.0
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59aa9fcc10>
# {'heuristic': 'hmax', 'search_algorithm': 'astar'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     go_south(b1)
#     go_south(b1)
#     go_south(b1)
#     go_south(b1)
#     go_south(b1)
#     go_south_west(b1)
#     save_person(b1, p0)
#     go_south(b1)
#     save_person(b1, p1)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 24\nAibr Preprocessing\n|F|:2\n|X|:4\n|A|:18\n|P|:0\n|E|:0\nH1 Setup Time (msec): 8\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=8.5\n g(n)= 1.0 h(n)=7.5\n g(n)= 2.0 h(n)=6.5\n g(n)= 3.0 h(n)=5.5\n g(n)= 4.0 h(n)=4.5\n g(n)= 5.0 h(n)=3.5\n g(n)= 6.0 h(n)=2.5\n g(n)= 7.0 h(n)=1.5\n g(n)= 8.0 h(n)=1.0\n g(n)= 9.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (go_south b1)\n1.0: (go_south b1)\n2.0: (go_south b1)\n3.0: (go_south b1)\n4.0: (go_south b1)\n5.0: (go_south_west b1)\n6.0: (save_person b1 p0)\n7.0: (go_south b1)\n8.0: (save_person b1 p1)\n\nPlan-Length:9\nMetric (Search):9.0\nPlanning Time (msec): 345\nHeuristic Time (msec): 23\nSearch Time (msec): 41\nExpanded Nodes:10\nStates Evaluated:134\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:0\nNumber of Duplicates detected:2\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
# ** Feedback of enhsp on instance
# ** /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/sailing/problem.pddl
# ** is 9.0
#
#
# <function SmacConfigurator.get_feedback_function.<locals>.planner_feedback at 0x7b59ab077a30>
# [INFO][smbo.py:327] Configuration budget is exhausted:
# [INFO][smbo.py:328] --- Remaining wallclock time: -0.5122451782226562
# [INFO][smbo.py:329] --- Remaining cpu time: inf
# [INFO][smbo.py:330] --- Remaining trials: 21
#
# Best Configuration found is:
#  {'heuristic': 'hadd', 'search_algorithm': 'gbfs'}
# {'heuristic': 'hadd', 'search_algorithm': 'gbfs'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     lift(hoist1, crate0, pallet1, distributor0)
#     lift(hoist0, crate1, pallet0, depot0)
#     load(hoist0, crate1, truck1, depot0)
#     drive(truck1, depot0, distributor0)
#     load(hoist1, crate0, truck1, distributor0)
#     unload(hoist1, crate1, truck1, distributor0)
#     drive(truck1, distributor0, distributor1)
#     unload(hoist2, crate0, truck1, distributor1)
#     drop(hoist1, crate1, pallet1, distributor0)
#     drop(hoist2, crate0, pallet2, distributor1)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 50\nAibr Preprocessing\n|F|:40\n|X|:0\n|A|:90\n|P|:0\n|E|:0\nH1 Setup Time (msec): 13\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=11.0\n g(n)= 1.0 h(n)=10.0\n g(n)= 2.0 h(n)=9.0\n g(n)= 3.0 h(n)=8.0\n g(n)= 4.0 h(n)=7.0\n g(n)= 5.0 h(n)=5.0\n g(n)= 6.0 h(n)=4.0\n g(n)= 7.0 h(n)=3.0\n g(n)= 8.0 h(n)=2.0\n g(n)= 9.0 h(n)=1.0\n g(n)= 10.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (lift hoist1 crate0 pallet1 distributor0)\n1.0: (lift hoist0 crate1 pallet0 depot0)\n2.0: (load hoist0 crate1 truck1 depot0)\n3.0: (drive truck1 depot0 distributor0)\n4.0: (load hoist1 crate0 truck1 distributor0)\n5.0: (unload hoist1 crate1 truck1 distributor0)\n6.0: (drive truck1 distributor0 distributor1)\n7.0: (unload hoist2 crate0 truck1 distributor1)\n8.0: (drop hoist1 crate1 pallet1 distributor0)\n9.0: (drop hoist2 crate0 pallet2 distributor1)\n\nPlan-Length:10\nMetric (Search):10.0\nPlanning Time (msec): 406\nHeuristic Time (msec): 21\nSearch Time (msec): 45\nExpanded Nodes:11\nStates Evaluated:69\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:4\nNumber of Duplicates detected:16\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
#
# Feedback on instance /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/depot/problem.pddl:
#
#  10.0
#
# {'heuristic': 'hadd', 'search_algorithm': 'gbfs'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     increment(c3)
#     increment(c3)
#     increment(c2)
#     increment(c3)
#     increment(c2)
#     increment(c1)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 16\nAibr Preprocessing\n|F|:0\n|X|:4\n|A|:8\n|P|:0\n|E|:0\nH1 Setup Time (msec): 7\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=3.0\n g(n)= 1.0 h(n)=2.0\n g(n)= 3.0 h(n)=1.0\n g(n)= 6.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (increment c3)\n1.0: (increment c3)\n2.0: (increment c2)\n3.0: (increment c3)\n4.0: (increment c2)\n5.0: (increment c1)\n\nPlan-Length:6\nMetric (Search):6.0\nPlanning Time (msec): 295\nHeuristic Time (msec): 9\nSearch Time (msec): 20\nExpanded Nodes:8\nStates Evaluated:28\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:0\nNumber of Duplicates detected:11\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
#
# Feedback on instance /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/counters/problem.pddl:
#
#  6.0
#
# {'heuristic': 'hadd', 'search_algorithm': 'gbfs'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     build_straight_oneway(junction1-0, junction2-0, road1)
#     build_straight_oneway(junction0-0, junction1-0, road3)
#     build_diagonal_oneway(junction0-1, junction1-0, road2)
#     build_straight_oneway(junction1-1, junction0-1, road0)
#     car_start(junction0-1, car1, garage1)
#     move_car_in_road(junction0-1, junction1-0, car1, road2)
#     move_car_out_road(junction0-1, junction1-0, car1, road2)
#     move_car_in_road(junction1-0, junction2-0, car1, road1)
#     move_car_out_road(junction1-0, junction2-0, car1, road1)
#     car_start(junction0-0, car0, garage0)
#     move_car_in_road(junction0-0, junction1-0, car0, road3)
#     move_car_out_road(junction0-0, junction1-0, car0, road3)
#     move_car_in_road(junction1-0, junction2-0, car0, road1)
#     car_arrived(junction2-0, car1)
#     move_car_out_road(junction1-0, junction2-0, car0, road1)
#     build_straight_oneway(junction2-1, junction1-1, road4)
#     car_arrived(junction2-0, car0)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 220\nAibr Preprocessing\n|F|:262\n|X|:0\n|A|:1220\n|P|:0\n|E|:0\nH1 Setup Time (msec): 60\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=164.0\n g(n)= 20.0 h(n)=64.0\n g(n)= 40.0 h(n)=36.0\n g(n)= 70.0 h(n)=8.0\n g(n)= 91.0 h(n)=7.0\n g(n)= 92.0 h(n)=6.0\n g(n)= 93.0 h(n)=5.0\n g(n)= 94.0 h(n)=4.0\n g(n)= 95.0 h(n)=3.0\n g(n)= 96.0 h(n)=2.0\n g(n)= 97.0 h(n)=1.0\n g(n)= 98.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (build_straight_oneway junction1_0 junction2_0 road1)\n1.0: (build_straight_oneway junction0_0 junction1_0 road3)\n2.0: (build_diagonal_oneway junction0_1 junction1_0 road2)\n3.0: (build_straight_oneway junction1_1 junction0_1 road0)\n4.0: (car_start junction0_1 car1 garage1)\n5.0: (move_car_in_road junction0_1 junction1_0 car1 road2)\n6.0: (move_car_out_road junction0_1 junction1_0 car1 road2)\n7.0: (move_car_in_road junction1_0 junction2_0 car1 road1)\n8.0: (move_car_out_road junction1_0 junction2_0 car1 road1)\n9.0: (car_start junction0_0 car0 garage0)\n10.0: (move_car_in_road junction0_0 junction1_0 car0 road3)\n11.0: (move_car_out_road junction0_0 junction1_0 car0 road3)\n12.0: (move_car_in_road junction1_0 junction2_0 car0 road1)\n13.0: (car_arrived junction2_0 car1)\n14.0: (move_car_out_road junction1_0 junction2_0 car0 road1)\n15.0: (build_straight_oneway junction2_1 junction1_1 road4)\n16.0: (car_arrived junction2_0 car0)\n\nPlan-Length:17\nMetric (Search):118.0\nPlanning Time (msec): 3015\nHeuristic Time (msec): 1384\nSearch Time (msec): 1781\nExpanded Nodes:127\nStates Evaluated:2222\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:4\nNumber of Duplicates detected:353\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
#
# Feedback on instance /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/citycar/problem.pddl:
#
#  118.0
#
# {'heuristic': 'hadd', 'search_algorithm': 'gbfs'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
#     go_south(b1)
#     go_south(b1)
#     go_south(b1)
#     go_south(b1)
#     go_south(b1)
#     go_south_west(b1)
#     save_person(b1, p0)
#     go_south(b1)
#     save_person(b1, p1)
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 23\nAibr Preprocessing\n|F|:2\n|X|:4\n|A|:18\n|P|:0\n|E|:0\nH1 Setup Time (msec): 8\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=8.5\n g(n)= 1.0 h(n)=7.5\n g(n)= 2.0 h(n)=6.5\n g(n)= 3.0 h(n)=5.5\n g(n)= 4.0 h(n)=4.5\n g(n)= 5.0 h(n)=3.5\n g(n)= 6.0 h(n)=2.5\n g(n)= 7.0 h(n)=1.5\n g(n)= 8.0 h(n)=1.0\n g(n)= 9.0 h(n)=0.0\nProblem Solved\n\nFound Plan:\n0.0: (go_south b1)\n1.0: (go_south b1)\n2.0: (go_south b1)\n3.0: (go_south b1)\n4.0: (go_south b1)\n5.0: (go_south_west b1)\n6.0: (save_person b1 p0)\n7.0: (go_south b1)\n8.0: (save_person b1 p1)\n\nPlan-Length:9\nMetric (Search):9.0\nPlanning Time (msec): 607\nHeuristic Time (msec): 20\nSearch Time (msec): 47\nExpanded Nodes:10\nStates Evaluated:134\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:0\nNumber of Duplicates detected:2\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
#
# Feedback on instance /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/sailing/problem.pddl:
#
#  9.0
#
# {'heuristic': 'hadd', 'search_algorithm': 'gbfs'}
# RESULT status: SOLVED_SATISFICING
# engine: SAT-enhsp
# plan: SequentialPlan:
# [LogMessage(level=<LogLevel.INFO: 2>, message='Domain parsed\nProblem parsed\nGrounding..\nGrounding Time: 15\nAibr Preprocessing\n|F|:9\n|X|:0\n|A|:10\n|P|:0\n|E|:0\nH1 Setup Time (msec): 7\nSetting horizon to:NaN\nRunning Greedy Best First Search\nh(n = s_0)=0.0\nProblem Solved\n\nFound Plan:\n\nPlan-Length:0\nMetric (Search):0.0\nPlanning Time (msec): 239\nHeuristic Time (msec): 0\nSearch Time (msec): 4\nExpanded Nodes:1\nStates Evaluated:0\nFixed constraint violations during search (zero-crossing):0\nNumber of Dead-Ends detected:0\nNumber of Duplicates detected:0\n'), LogMessage(level=<LogLevel.ERROR: 4>, message='')]
# Result found.
#
#
# Feedback on instance /usr/local/lib/python3.10/dist-packages/up_ac/test_problems/safe_road/problem.pddl:
#
#  0.0
#
#
# Average performance on 5 instances: 28.6
#
#
# Saved best configuration in ./incumbent_enhsp.json
